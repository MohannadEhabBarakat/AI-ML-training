# %% [markdown]
# # Data loading and visualization
# ## Part 1 of the series of notebooks to solve the competition
#
# In this notebook, data analysis and visualization is performed on training and testing data sets. It is inspired by the available competition notebooks and the discussion form.
#
# ## Content:
#   - [Import required modules](#Import%20required%20modules)
#   - [load data](#load%20data)

# %% [markdown]
# ### Import required modules

# %%
# jupyter majec function to print images inlined
# %matplotlib inline 

import numpy as np # linear algebra
import pandas as pd # data processing
import matplotlib.pyplot as plt # ploting.
import seaborn as sns # more cool plotting 
from nltk.corpus import stopwords # load stoping words
from nltk.tokenize import word_tokenize # word tokenizer
import operator

pd.set_option('display.max_colwidth', -1)
pd.options.display.max_rows = 4000

import re # Regular expression

# %% [markdown]
# ### load data

# %%
dataPath = 'dataset'

#Training data
train = pd.read_csv(dataPath+'/train.csv')
# Testing data 
test = pd.read_csv(dataPath+'/test.csv')

for col in train.columns:
    train[col] = train[col].astype(str)
for col in test.columns:
    test[col] = test[col].astype(str)

print("Train data of shape",train.shape)
print("Test data of shape",test.shape)
# Out:
# Train data of shape (27486, 4)
# Test data of shape (3535, 3)

# %%
# train data sample
elements_from_head=100 # number of elements to show from head

print("Train data first", elements_from_head, "samples")
train.head(elements_from_head)
# Out:
# Train data first 100 samples
#         textID                                               text  \
# 0   a3d0a7d5ad  Spent the entire morning in a meeting w/ a ven...
# 1   251b6a6766      Oh! Good idea about putting them on ice cream
# 2   c9e8d1ef1c  says good (or should i say bad?) afternoon!  h...
# 3   f14f087215         i dont think you can vote anymore! i tried
# 4   bf7473b12d             haha better drunken tweeting you mean?
# 5   1915bebcb3                       headache  wanna see my Julie
# 6   2ab82634d5  had an awsome salad! I recommend getting the S...
# 7   a5a1c996c0   fine! Going to do my big walk today 20 or so ...
# 8   a182b2638e        Thank a yoou  how are you? #TwitterTakeover
# 9   1dcb6fdb13  Why don't adobe realise no one WANTS to pay fo...
# 10  6bff31375d                    PRD take a long time to review!
# 11  e1ed43bebe  _2008 Well, having to revise them!  Was to do ...
# 12  41fd07f670                                   Miss you my dear
# 13  bc0f2cb758  Have just bought a TV tuner for my laptop.  He...
# 14  0e6fb9153c          ya mine too but for very different reason
# 15  49c7c9c6e2  Today Dan bought me Bio Dome AND the Reality B...
# 16  e6f5e9817d                              oo noo thats not good
# 17  fee2d997a9        misses her phone... having no service sucks
# 18  459fc2a7c8      so i have like no more friends it's kinda sad
# 19  1a760553fc  i have perused the #fieldnotes website and it ...
# 20  1e857fecf5                 ....welcome to public transport  X
# 21  22adf200c3  Also I popped the phone open and got all that ...
# 22  bae5414377                                              uh oh
# 23  22744e80f7  12:46AM. HAppy birthday little sister of mine....
# 24  e487233140   aaawww  no worries fresh start to work on gro...
# 25  22e66a73af     oh, /me still hasn't got around to starting it
# 26  01cfa3807e  is sooo tired and too busy to tweet  im glad t...
# 27  7f59b000cd                                  what's going on ?
# 28  127b2ac78c   I can't, I'm studying so I don't fail  Come o...
# 29  a6c77ff610  Just watched &quot;Marley &amp; Me.&quot; Cute...
# ..         ...                                                ...
# 70  f29df52d91   I want to know when the auditions are Mander!...
# 71  196107983d   I'll stop by for a bit when I'm off.  But hav...
# 72  2f2542a3c2  Whoa, I didn't mean to sleep for more than an ...
# 73  134b4e3267  In bed after a good last saturday in ec. I'm g...
# 78                                             stress  negative
# 79                            is watching the canucks   neutral
# 80                                        good person  positive
# 81  blerg, **** you Monday, why must you always co...   neutral
# 82                                             hoping  positive
# 83                       gprof problem on Mac  why ??   neutral
# 84                                             e nice  positive
# 85                                    ! How exciting!  positive
# 86  done with the fkn exam! n just bought the moth...   neutral
# 87                                   had a good time.  positive
# 88  Goodnight Beautiful world  sweet dreams. olive...  positive
# 89                                               love  positive
# 90                           Yay for St Louis traffic   neutral
# 91                                     I have to pee.   neutral
# 92  hhahaa!    its well strange just woke up to an...   neutral
# 93                                           awesome!  positive
# 94  i got followed by one that says she doesn't ta...   neutral
# 95    uh wait...i thought this was the 29th...tonight   neutral
# 96                                       doesn't like  negative
# 97                                    Great meeting..  positive
# 98  &quot;We did it we did it oh yea yea yea no ea...   neutral
# 99  hey adt, guess what. my princelple's number pl...   neutral
#
# [100 rows x 4 columns]

# %%
# train data sample
elements_random=100 # number of random elements to show

print("Train data random", elements_random, "samples")
train.sample(elements_random)
# Out:
# Train data random 100 samples
#            textID  \
# 19949  0688b31fc2
# 23678  0977cf06ba
# 289    e578b04e2a
# 24472  8dd4fb2c3f
# 22517  f6de3a1120
# 24728  30cc3c9612
# 4216   3ab12ae6a0
# 26056  f7afbbafe4
# 14286  16d37ed26a
# 14856  d2da9db0e5
# 133    b3aa6f64d8
# 23853  85f7905304
# 17249  7474600877
# 1840   8f45d14d87
# 2487   4f85b258f7
# 20359  bd2c1c0f1d
# 10436  c05123a42f
# 1210   7bb1247eb5
# 242    086a1d96ed
# 18187  ec23d0e4d0
# 23674  2461bae848
# 14006  05be2d3dc7
# 243    5d5178af59
# 1522   3776ec1e45
# 23684  baf7ec680a
# 23210  bda1d7b693
# 2917   548de387bc
# 15765  943b44d2f1
# 20597  31f07da370
# 25572  89867c41e7
# ...           ...
# 4885   a24ef21137
# 23128  cf29e364fe
# 5709   bc2bc1835f
# 1174   17dd98db9a
# 6243   6a0d76066c
# 3886   89764b6d5a
# 27316  0d450d9607
# 1705   a15a5d5645
# 27416  496086d5a5
# 2003   814f378242
# 14926  479e513584
# 3839   3eab4d3d25
# 12227  13f981fa30
# 5994   fcef0b8642
# 5064   847d69da87
# 25616  500d5b1751
# 19789  f618970fb0
# 3200   439803cf54
# 12244  5d6c718979
# 8829   2a76996986
# 12905  c16a52d2a7
# 15573  6175d57cf0
# 25928  900e2a6ece
# 26087  af45cd98f8
# 15145  a49ab2fd9b
# 22603  752bed813d
# 19664  4541da9878
# 3135   07e2021536
# 12710  947a309643
# 17613  0cf9858660
#
#                                                                                                                                              text  \
# 19949   still here unfortunately!!!!
# 23678   haha sounds like your going to have heaps of fun  ****
# 289    i need to see ...now! someone buy me a plane ticket, please?
# 24472  There are some great honey based recipes for you &amp; the kids to download  at -  http://twurl.nl/ltlny8 - Join in the fun for honey week
# 22517  this is a horrible day.
# 24728   I gave up following  - She seems really nice but clutters the hell out of my feed.  It got annoying.
# 4216   playing with  on a cool new website... hopefully ready very soon
# 26056  Eh, I've gotta go to bed anyways. Goodnight.
# 14286  finish some sketches und then go out an skate! Yeeeehaaa! got a new deck
# 14286  neutral
# 14856  positive
# 133    positive
# 23853  negative
# 17249  positive
# 1840   negative
# 2487   neutral
# 20359  neutral
# 10436  neutral
# 1210   negative
# 242    negative
# 18187  positive
# 23674  positive
# 14006  negative
# 243    negative
# 1522   neutral
# 23684  positive
# 23210  neutral
# 2917   positive
# 15765  negative
# 20597  positive
# 25572  neutral
# ...        ...
# 4885   neutral
# 23128  negative
# 5709   neutral
# 1174   neutral
# 6243   neutral
# 3886   neutral
# 27316  negative
# 1705   neutral
# 27416  positive
# 2003   neutral
# 14926  negative
# 3839   negative
# 12227  positive
# 5994   negative
# 5064   positive
# 25616  negative
# 19789  neutral
# 3200   neutral
# 12244  neutral
# 8829   neutral
# 12905  positive
# 15573  negative
# 25928  neutral
# 26087  neutral
# 15145  neutral
# 22603  neutral
# 19664  positive
# 3135   neutral
# 12710  positive
# 17613  negative
#
# [100 rows x 4 columns]

# %%
# test data sample

print("Test data first", elements_from_head, "samples")
test.head(elements_from_head)
# Out:
# Test data first 10 samples
#        textID                                               text sentiment
# 0  11aa4945ff   http://twitpic.com/67swx - i wish i was calli...  positive
# 1  fd1db57dc0              i'm done.haha. HOUSE MD marathon ulet  positive
# 2  2524332d66                      I'm concerned for that family  positive
# 3  0fb19285b2  HEY GUYS IT'S WORKING NO NEED TO WORRY. i have...  positive
# 4  e6c9e5e3ab                                      26th February   neutral
# 5  311d2b185b  Tracy and Berwick breaks my achy breaky heart ...  negative
# 6  95dfefd4e7  Well off 2 bed...cant wait 2 party 4 Mother's ...  positive
# 7  739f17cfe1  Oh yeah the camera clipping problems with Void...  positive
# 8  c6322a85c2     _Layne  hmm.. what's ur fav movie?? tv shows??   neutral
# 9  b4401d6b4d   salt and vinegar, cheese and onion make your ...  negative

# %%
print("Test data random", elements_random, "samples")
test.sample(elements_random)
# Out:
# Test data random 10 samples
#           textID                                               text sentiment
# 2480  07dbf16cf0   ya. i was suffering the whole day yesterday. ...   neutral
# 1285  132462ca21  : unfortunately not.  I have to take it to a r...  negative
# 2426  4d9a27e25a   don't you need a server and someone who knows...   neutral
# 2795  2d5b920414            I'll have to wait for the YouTube links   neutral
# 1684  b667160840                                   then ill post it   neutral
# 1612  792c97a352  my best friends bought something which i reall...  positive
# 2657  51bdb4d865    Feeling very tierd! too much college work!!!!!!  negative
# 3103  c12a98d8f3           i so can't be bothered working tomorrow!  positive
# 3317  ec8507eef4   haha. Thanks Shannon.  3 out of 5 boats got f...  positive
# 3422  558fe1316b  On a 10min brake. At wrrkk ... its 11:06 and i...   neutral

# %% [markdown]
# ### Data analysis

# %%
pos,neg,nat=train['sentiment'].value_counts()


print("Training data")
print("Number of positive is {}, number of negative is {}, and number of neutral is {}".format(pos,neg,nat))
sns.countplot(x='sentiment',data=train)
print("Train Data Sentiment")
# Out:
# Training data
# Number of positive is 11118, number of negative is 8582, and number of neutral is 7786
# Train Data Sentiment

# %%
pos2,neg2,nat2=test['sentiment'].value_counts()


print("Testing data")
print("Number of positive is {}, number of negative is {}, and number of neutral is {}".format(pos2,neg2,nat2))
sns.countplot(x='sentiment',data=train)
print("Test Data Sentiment")
# Out:
# Testing data
# Number of positive is 1430, number of negative is 1104, and number of neutral is 1001
# Test Data Sentiment

# %%
sentament = ["neutral","positive","negative"]
diff=[nat/train.shape[0]-nat2/test.shape[0], pos/train.shape[0]-pos2/test.shape[0], neg/train.shape[0]-neg2/test.shape[0]]

print("Train - Test")
print("Number of positive is {}, number of negative is {}, and number of neutral is {}".format(diff[1],diff[2],diff[0]))

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(sentament,diff)
plt.show()
# Out:
# Train - Test
# Number of positive is -2.9332150166982984e-05, number of negative is -7.383468256078052e-05, and number of neutral is 0.00010316683272781901

# %% [markdown]
# ### Length distrepution befor data cleaning

# %%
#for train text

lens = [len(x) for x in train.text]
plt.figure(figsize=(12, 5));
print ("max: {}, min: {}, mean: {:.5}".format(max(lens), min(lens), np.mean(lens)))
sns.distplot(lens);
plt.title('Train text length distribution')
# Out:
# max: 165, min: 3, mean: 68.725
# Text(0.5, 1.0, 'Train text length distribution')

# %%
# for train selected_text

lens = [len(x) for x in train.selected_text]
plt.figure(figsize=(12, 5));
print ("max: {}, min: {}, mean: {:.5}".format(max(lens), min(lens), np.mean(lens)))
sns.distplot(lens);
plt.title('Train selected_text length distribution')
# Out:
# max: 141, min: 1, mean: 36.747
# Text(0.5, 1.0, 'Train selected_text length distribution')

# %%
#for test text

lens = [len(x) for x in test.text]
plt.figure(figsize=(12, 5));
print ("max: {}, min: {}, mean: {:.5}".format(max(lens), min(lens), np.mean(lens)))
sns.distplot(lens);
plt.title('Test text length distribution')
# Out:
# max: 155, min: 4, mean: 68.188
# Text(0.5, 1.0, 'Test text length distribution')

# %% [markdown]
# ### Word frequency function

# %%
def word_frequency(data,return_word_frequency):
    for word in data.split():
        if return_word_frequency.get(word, False): return_word_frequency[word]+=1
        else: return_word_frequency[word]=1
    return return_word_frequency

# %% [markdown]
# ### Data cleaning

# %%
def get_char_only(text):
    chars = re.compile(r"[^a-zA-Z]")
    return chars.sub(r' ',text)

def remove_URL(text):
    url = re.compile(r'https?://\S+|www\.\S+')
    return url.sub(r'',text)

def remove_html(text):
    html=re.compile(r'<.*?>')
    text=html.sub(r'',text)
    return text
    
def remove_stoping_words(text):
    stop=set(stopwords.words('english'))
    return " ".join([x for x in word_tokenize(text) if x not in stop])

# def remove_stoping_words(data):
#     return [ remove_stopwords_statment(i) for i in data]

def remove_emoji(text): 
    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F"  # emoticons
                               u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                               u"\U0001F680-\U0001F6FF"  # transport & map symbols
                               u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                               u"\U00002702-\U000027B0"
                               u"\U000024C2-\U0001F251"
                               "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)

def remove_tag(text):
    return ' '.join(re.sub("[@][\w_-]+"," ",text).split())


def clean_data(data): # data must by list only
    data= data.apply(lambda x : remove_html(x))
    data= data.apply(lambda x : remove_URL(x))
    data= data.apply(lambda x : remove_emoji(x))
    data= data.apply(lambda x : remove_tag(x))
    data= data.apply(lambda x : get_char_only(x))
    data= data.apply(lambda x : remove_stoping_words(x))    
    return data

def clean_train():
    train_df=train.copy()
    train_df.text=clean_data(data=train.text)
    train_df.selected_text=clean_data(train.selected_text)
    return train_df
    
def clean_test():
    test.text=clean_data(test.text)

# %%
train_df = clean_train()
train_df.head(100)
# Out:
#         textID                                               text  \
# 0   a3d0a7d5ad  Spent entire morning meeting w vendor boss hap...
# 1   251b6a6766                     Oh Good idea putting ice cream
# 2   c9e8d1ef1c                        says good say bad afternoon
# 3   f14f087215                      dont think vote anymore tried
# 2                         says good say bad afternoon   neutral
# 3                             dont think vote anymore  negative
# 4                                              better  positive
# 5                                            headache  negative
# 6                                        awsome salad  positive
# 7                                                fine  positive
# 8                                               Thank  positive
# 9   Why adobe realise one WANTS pay Photoshop et a...   neutral
# 10                          PRD take long time review   neutral
# 11  Well revise Was gardening I guess hoovering wa...   neutral
# 12                                          Miss dear  negative
# 13   Have bought TV tuner laptop He I deserve present  positive
# 14                           ya mine different reason   neutral
# 15                                    tummy happy Boo  negative
# 16                                               good  negative
# 17                                      service sucks  negative
# 18                                            friends  negative
# 19  perused fieldnotes website good bad must retur...   neutral
# 20                         welcome public transport X   neutral
# 21                                            goddamn  negative
# 22                                              uh oh  negative
# 23                  HAppy birthday little sister mine  positive
# 24                                     aaawww worries  positive
# 25                       oh still got around starting   neutral
# 26                                               glad  positive
# 27                                              going   neutral
# 28  I I studying I fail Come I make u tortellini c...   neutral
# 29                                              mp Me  positive
# ..                                                ...       ...
# 70     I want know auditions Mander Text reply please   neutral
# 71      I stop bit I But rush rehearsal quiet tonight   neutral
# 72                             Whoa I mean sleep hour   neutral
# 73  In bed good last saturday ec I gon na miss pla...  negative
# 74                       Is Bee Busy talk buddy Yahoo   neutral
# 75                                   I need followers   neutral
# 76                                   Im way brookings   neutral
# 77                     Thanks It bit comfort zone fun   neutral
# 78                                             stress  negative
# 79                                   watching canucks   neutral
# 80                                        good person  positive
# 81  blerg Monday must always come Decent weekend n...   neutral
# 82                                             hoping  positive
# 83                                  gprof problem Mac   neutral
# 84                                             e nice  positive
# 85                                       How exciting  positive
# 86  done fkn exam n bought mothers day gift finall...   neutral
# 87                                          good time  positive
# 88  Goodnight Beautiful world sweet dreams olive j...  positive
# 89                                               love  positive
# 90                               Yay St Louis traffic   neutral
# 91                                              I pee   neutral
# 92  hhahaa well strange woke empty house ahah loll...   neutral
# 93                                            awesome  positive
# 94  got followed one says talk quot god people quo...   neutral
# 95                         uh wait thought th tonight   neutral
# 96                                               like  negative
# 97                                      Great meeting  positive
# 98  quot We oh yea yea yea eating tonite woo eatin...   neutral
# 99  hey adt guess princelple number plate adt well...   neutral
#
# [100 rows x 4 columns]

# %%
train_text_freq={}
for i in train_df.text:
    train_count_freq = word_frequency(i,train_text_freq)
    
# train_text_freq = train_df.text.apply(lambda x : word_frequency(x,train_text_freq) )

sorted_train_text_freq = sorted(train_text_freq.items(), key=operator.itemgetter(1))
print(sorted_train_text_freq[-11:-1])
# Out:
# [('going', 951), ('today', 1061), ('work', 1097), ('got', 1097), ('go', 1215), ('good', 1273), ('quot', 1292), ('like', 1305), ('get', 1388), ('day', 1679)]

# %%
train_selected_text_freq={}
for i in train_df.selected_text:
    train_selected_text_freq = word_frequency(i,train_selected_text_freq)
    
# train_text_freq = train_df.text.apply(lambda x : word_frequency(x,train_text_freq) )

sorted_train_selected_text_freq = sorted(train_selected_text_freq.items(), key=operator.itemgetter(1))
print(sorted_train_selected_text_freq[-11:-1])
# Out:
# [('today', 536), ('got', 569), ('work', 593), ('quot', 607), ('go', 660), ('like', 746), ('love', 749), ('get', 750), ('day', 877), ('good', 1011)]
